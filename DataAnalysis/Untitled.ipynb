# %%
import pandas as pd

# %%
df1 = pd.read_excel('시도구군별_음주운전_데이터_2005_2019.xls', header=[0], index_col=[0,1])
df1
# Out:
#          2005   2006   2007   2008   2009   2010   2011   2012   2013   2014  \
# 강원 강릉시    245    221    239    166    207    175    174    160    143    130
#    고성군     21     14     21     21     27     29     30     19     26     10
#    동해시     52     49     49     44     59     58     46     51     48     34
#    삼척시     49     40     33     34     40     19     27     48     39     40
#    속초시     90     78     62     72     89     92     89     77     59     68
# ...       ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 충북 청원군     78     96     96    122    111    110    129    140    127     50
#    청주시    314    386    369    364    413    432    499    542    498    513
#    충주시     94    137    212    145    141    112    191    147    150    137
#    합계     779    987   1001    991   1027    986   1260   1233   1162   1035
# 합계 합계   26460  29990  28416  26873  28207  28641  28461  29093  26589  24043
#
#          2015   2016   2017   2018   2019
# ...

# %%
df1 = df1.xs('합계', level=1)
df1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-426fafa25f48> in <module>
# ----> 1 df1 = df1.xs('합계', level=1)
#       2 df1
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in xs(self, key, axis, level, drop_level)
#    3515         labels = self._get_axis(axis)
#    3516         if level is not None:
# -> 3517             loc, new_ax = labels.get_loc_level(key, level=level, drop_level=drop_level)
#    3518
#    3519             # create the tuple of the indexer
#
# AttributeError: 'Index' object has no attribute 'get_loc_level'

# %%
df1.to_excel('시도구군별_음주운전_데이터_2005_2019.xls')

# %%
df2 = pd.read_excel('행정구역_시군구별_인구수_2005_2019.xls', header=[0], index_col=[0,1])
df2
# Out:
#             2005      2006      2007      2008      2009      2010      2011  \
# 강원 강릉시    224391    222016    220484    218399    217464    218503    217571
#    고성군     31964     31285     30383     30172     30272     30112     30057
#    동해시     99230     97497     96652     95652     95271     95236     95804
#    명주군         0         0         0         0         0         0         0
#    삼척군         0         0         0         0         0         0         0
# ...          ...       ...       ...       ...       ...       ...       ...
# 충북 청주시    630939    626679    633286    638663    643161    655971    661946
#    충주시    205907    204610    205064    206372    206613    208481    208433
#    합계    1488803   1494559   1506608   1519587   1527478   1549528   1562903
#    흥덕구    372341    370340    382728    392319    399384    414382    420325
# 합계 합계   48782274  48991779  49268928  49540367  49773145  50515666  50734284
#
# ...

# %%
df2 = df2.xs('합계', level=1)

# %%
df2.to_excel('행정구역_시군구별_인구수_2005_2019.xls')
