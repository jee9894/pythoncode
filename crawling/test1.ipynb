# %%
import requests

r = requests.get('https://api.github.com/events')

# %%
r
# Out:
# <Response [200]>

# %%
r = requests.get('https://naver.com')
r
# Out:
# <Response [200]>

# %%
r.text
# Out:
# '\n<!doctype html>                <html lang="ko" data-dark="false"> <head> <meta charset="utf-8"> <title>NAVER</title> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"> <meta name="apple-mobile-web-app-title" content="NAVER"/> <meta name="robots" content="index,nofollow"/> <meta name="description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta property="og:title" content="네이버"> <meta property="og:url" content="https://www.naver.com/"> <meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta property="og:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta name="twitter:card" content="summary"> <meta name="twitter:title" content=""> <meta name="twitter:url" content="https://www.naver.com/"> <meta name="twitter:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta name="twitter:description" content="네이버 메인에서 다양
# ...

# %%
payload = {'key1':'value1', 'key2':'value2'}
r = requests.get('https://httpbin.org/get', params = payload)
r
# Out:
# <Response [200]>

# %%
r.text
# Out:
# '{\n  "args": {\n    "key1": "value1", \n    "key2": "value2"\n  }, \n  "headers": {\n    "Accept": "*/*", \n    "Accept-Encoding": "gzip, deflate", \n    "Host": "httpbin.org", \n    "User-Agent": "python-requests/2.22.0", \n    "X-Amzn-Trace-Id": "Root=1-5f0f9f18-e650b9b3df66432d5d22d302"\n  }, \n  "origin": "1.221.125.150", \n  "url": "https://httpbin.org/get?key1=value1&key2=value2"\n}\n'

# %%
r.url
# Out:
# 'https://httpbin.org/get?key1=value1&key2=value2'

# %%
r = requests.get('http://localhost:5000/content/lbkf')
r
# Out:
# <Response [200]>

# %%
r.text
# Out:
# '<!doctype html>\n<html lang="en">\n\n<head>\n  <!-- Required meta tags -->\n<meta charset="utf-8">\n<meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no">\n<!-- Bootstrap CSS -->\n<link href="https://fonts.googleapis.com/css2?family=Cute+Font&display=swap" rel="stylesheet">\n<link rel="stylesheet" href="https://stackpath.bootstrapcdn.com/bootstrap/4.2.1/css/bootstrap.min.css" integrity="sha384-GJzZqFGwb1QTTN6wy59ffF1BuGJpLSa9DkKMp0DgiMDm4iYMj70gZWKYbI706tWS" crossorigin="anonymous">\n<link href="https://fonts.googleapis.com/css?family=Do+Hyeon" rel="stylesheet">\n<script src="https://code.jquery.com/jquery-3.3.1.slim.min.js" integrity="sha384-q8i/X+965DzO0rT7abK41JStQIAqVgRVzpbzo5smXKp4YfRvH+8abtTE1Pi6jizo" crossorigin="anonymous"></script>\n<script src="https://cdnjs.cloudflare.com/ajax/libs/popper.js/1.14.6/umd/popper.min.js" integrity="sha384-wHAiFfRlMFy6i5SRaxvfOCifBUQy1xHdJ/yoi7FRNXMRBu5WHdZYu1hA6ZOblgut" crossorigin="anonymous"></script>\n<scrip
# ...

# %%
r.url
# Out:
# 'http://localhost:5000/content/lbkf'

# %%
r.is_redirect
# Out:
# False

# %%
r.status_code
# Out:
# 200

# %%
data = {'sm':'top_hty','fbm':'1','ie':'utf8','query':'대구'}

# %%
r = requests.get('https://search.naver.com/search.naver', params = data)

# %%
r.text
# Out:
# '<!doctype html> <html lang="ko"> <head> <meta charset="utf-8"> <meta name="referrer" content="always">  <meta name="format-detection" content="telephone=no,address=no,email=no"> <meta name="viewport" content="width=device-width,initial-scale=1.0,maximum-scale=2.0"> <meta property="og:title" content="대구 : 네이버 통합검색"/> <meta property="og:image" content="https://ssl.pstatic.net/sstatic/search/common/og_v3.png"> <meta property="og:description" content="\'대구\'의 네이버 통합검색 결과입니다."> <meta name="description" lang="ko" content="\'대구\'의 네이버 통합검색 결과입니다."> <title>대구 : 네이버 통합검색</title> <link rel="shortcut icon" href="https://ssl.pstatic.net/sstatic/search/favicon/favicon_191118_pc.ico">  <link rel="search" type="application/opensearchdescription+xml" href="https://ssl.pstatic.net/sstatic/search/opensearch-description.https.xml" title="Naver" /><link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/sstatic/search/pc/css/search1_200528.css"> <link rel="stylesheet" type="text/css" href="
# ...

# %%
r.url
# Out:
# 'https://search.naver.com/search.naver?sm=top_hty&fbm=1&ie=utf8&query=%EB%8C%80%EA%B5%AC'

# %%
r.cookies
# Out:
# <RequestsCookieJar[Cookie(version=0, name='_naver_usersession_', value='apog/AneJyGH92pYcMzJoQ==', port=None, port_specified=False, domain='.naver.com', domain_specified=True, domain_initial_dot=True, path='/', path_specified=True, secure=False, expires=1594860400, discard=False, comment=None, comment_url=None, rest={}, rfc2109=False), Cookie(version=0, name='nx_ssl', value='2', port=None, port_specified=False, domain='.naver.com', domain_specified=True, domain_initial_dot=True, path='/', path_specified=True, secure=False, expires=1597452100, discard=False, comment=None, comment_url=None, rest={}, rfc2109=False), Cookie(version=0, name='page_uid', value='Uw+AesprvxsssDlrvq0ssssstEG-478685', port=None, port_specified=False, domain='.naver.com', domain_specified=True, domain_initial_dot=True, path='/', path_specified=True, secure=False, expires=None, discard=True, comment=None, comment_url=None, rest={}, rfc2109=False)]>

# %%
r.headers
# Out:
# {'Date': 'Thu, 16 Jul 2020 00:41:40 GMT', 'Content-Type': 'text/html; charset=UTF-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Set-Cookie': 'page_uid=Uw+AesprvxsssDlrvq0ssssstEG-478685; path=/; domain=.naver.com, _naver_usersession_=apog/AneJyGH92pYcMzJoQ==; path=/; expires=Thu, 16-Jul-20 00:46:40 GMT; domain=.naver.com, nx_ssl=2; Domain=.naver.com; Path=/; Expires=Sat, 15-Aug-2020 00:41:40 GMT;', 'X-Frame-Options': 'SAMEORIGIN', 'X-XSS-Protection': '1; report=/p/er/post/xss', 'Cache-Control': 'no-cache, no-store, must-revalidate, max-age=0', 'Pragma': 'no-cache', 'Vary': 'Accept-Encoding', 'Content-Encoding': 'gzip', 'Server': 'nxg'}

# %%
r.connection

# %%
payload = {'key1': 'value1', 'key2': ['value2', 'value3']}

r = requests.get('https://httpbin.org/get', params=payload)
r.url
# Out:
# 'https://httpbin.org/get?key1=value1&key2=value2&key2=value3'

# %%
r = requests.get('http://blogfiles.naver.net/20160701_297/eogk8709_1467331642060pX7gq_JPEG/11.jpg')

from PIL import Image
from io import BytesIO

i = Image.open(BytesIO(r.content))

# %%
i
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x500 at 0x29FA9146B88>

# %%
r = requests.get('https://api.github.com/events')
j = r.json()
j[0]['actor']['id']
# Out:
# 39814207

# %%
data = {'userid':'a'}
r = requests.post('http://localhost:5000/ajaxlist', data=data)
r.json()
# Out:
# [{'useradd': 'ghjgyj',
#   'userage': 28,
#   'usergender': 'male',
#   'userid': 'abc',
#   'usermail': 'ghjyj@nsdjfefj',
#   'username': 'vvvv',
#   'userpw': '1234',
#   'usertel': 'hjgyj'},
#  {'useradd': '부산시 남구',
#   'userage': 33,
#   'usergender': 'male',
#   'userid': 'asd',
#   'usermail': 'gildong@gmail.com',
#   'username': '길동',
#   'userpw': '1234',
#   'usertel': '010-1234-1234'}]

# %%
r.url
# Out:
# 'http://localhost:5000/ajaxlist'

# %%
# data = {'useradd': '부산시 해운대구',
#   'userage': 33,
#   'usergender': 'male',
#   'userid': 'abcd123',
#   'useremail': 'bbbff@gmail.com',
#   'username': '길동',
#   'userpw': '1234',
#   'usertel': '010-1234-1234'}
data = [
  ('useradd', '대구시 달서구'),
  ('userage', 33),
  ('usergender', 'male'),
  ('userid', 'imaginedragon'),
  ('useremail', 'bbbff@gmail.com'),
  ('username', '길동'),
  ('userpw', '1234'),
  ('usertel', '010-1234-1234')
]

# %%
r = requests.post('http://localhost:5000/usersform', data=data, allow_redirects=False)

# %%
r
# Out:
# <Response [302]>

# %%
r.url
# Out:
# 'http://localhost:5000/usersform'

# %%
r.history
# Out:
# []

# %%
payload_tuples = [('key1','value1'), ('key1','value2')]
r1 = requests.post('https://httpbin.org/post', data=payload_tuples)
payload_dict = {'key1':['value1','value2']}
r2 = requests.post('https://httpbin.org/post', data=payload_dict)
r1.text == r2.text
# Out:
# False

# %%
r2.text
# Out:
# '{\n  "args": {}, \n  "data": "", \n  "files": {}, \n  "form": {\n    "key1": [\n      "value1", \n      "value2"\n    ]\n  }, \n  "headers": {\n    "Accept": "*/*", \n    "Accept-Encoding": "gzip, deflate", \n    "Content-Length": "23", \n    "Content-Type": "application/x-www-form-urlencoded", \n    "Host": "httpbin.org", \n    "User-Agent": "python-requests/2.22.0", \n    "X-Amzn-Trace-Id": "Root=1-5f0faea1-3aaca5946e57fc94e568d7a4"\n  }, \n  "json": null, \n  "origin": "1.221.125.150", \n  "url": "https://httpbin.org/post"\n}\n'

# %%
'hi'
# Out:
# 'hi'
